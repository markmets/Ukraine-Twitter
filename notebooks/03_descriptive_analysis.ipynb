# %% [markdown]
# # 03 — Descriptive Analysis
#
# Loads the cleaned tweet dataset and produces descriptive statistics and
# time-series plots of Twitter attention towards Ukraine 2008–2023.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

PROCESSED_DIR = Path('../data/processed')
FIGURES_DIR = Path('../results/figures')
TABLES_DIR = Path('../results/tables')
FIGURES_DIR.mkdir(parents=True, exist_ok=True)
TABLES_DIR.mkdir(parents=True, exist_ok=True)

sns.set_theme(style='whitegrid')

# %%
# Load cleaned dataset
clean_path = PROCESSED_DIR / 'tweets_clean.csv'
if clean_path.exists():
    tweets = pd.read_csv(clean_path, parse_dates=['created_at'])
    print(f'Loaded {len(tweets):,} tweets')
    print(tweets.dtypes)
else:
    print('Run 02_preprocessing.ipynb first')

# %%
# Monthly tweet volume
if 'tweets' in dir():
    monthly = tweets.groupby('month').size().reset_index(name='tweet_count')
    monthly.to_csv(TABLES_DIR / 'monthly_counts.csv', index=False)

    fig, ax = plt.subplots(figsize=(14, 5))
    ax.plot(monthly['month'].astype(str), monthly['tweet_count'])
    ax.set_title('Monthly Twitter attention towards Ukraine (2008–2023)')
    ax.set_xlabel('Month')
    ax.set_ylabel('Number of tweets')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    fig.savefig(FIGURES_DIR / 'monthly_tweet_volume.png', dpi=150)
    plt.show()
    print('Figure saved')
